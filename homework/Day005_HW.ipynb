# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''
import requests
r = requests.get('https://www.dcard.tw/_api/forums/relationship/posts?popular=true')
response = r.text

# %%
import json
datas = json.loads(response)
datas
# Out:
# [{'id': 232995333,
#   'title': '女友常幫我口交的秘密(心情複雜)',
#   'excerpt': '我跟女友在一起三年多，她常常幫我口交。常常，不只是個形容詞，而是身體力行的副詞！（已更正，不是動詞。做愛的時候就不提了，洗澡的時候、在家吃飯的時候（她食量很小一下就吃完了，就吃我的雞雞）、我幫她收衣服',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '42851318-b9e2-4a75-8a05-9fe180becefe',
#   'replyId': None,
#   'createdAt': '2020-02-01T08:09:50.628Z',
#   'updatedAt': '2020-02-02T02:01:07.313Z',
#   'commentCount': 286,
#   'likeCount': 24047,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['愛情', '口交'],
#   'meta': {'layout': 'classic'},
#   'forumName': '感情',
#   'forumAlias': 'relationship',
#   'gender': 'M',
#   'school': '國立政治大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 21678},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2206},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 114},
# ...

# %%
len(datas)
# Out:
# 30

# %%
for data in datas:
    print(data.keys())
    print("\n")
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
#
#
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])
#
#
# ...

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
comments=0
likes=0
'''
Your Code
'''
for data in datas:
    print('標題:{}'.format(data['title']))
    print('貼文時間:{}'.format(data['createdAt']))
    print('留言人數:{}'.format(data['commentCount']))
    comments=comments+data['commentCount']
    print('按讚數:{}'.format(data['likeCount']))
    likes=likes+data['likeCount']
    print('\n')
# Out:
# 標題:女友常幫我口交的秘密(心情複雜)
# 貼文時間:2020-02-01T08:09:50.628Z
# 留言人數:286
# 按讚數:24047
#
#
# 標題:小學班長，成了我十五年後的新娘
# 貼文時間:2020-02-01T13:38:20.304Z
# 留言人數:294
# 按讚數:15195
#
#
# 標題:更）那一夜的大吵
# 貼文時間:2020-02-01T12:14:47.922Z
# 留言人數:78
# 按讚數:4376
#
#
# 標題:我的胖胖女友
# 貼文時間:2020-02-01T08:11:37.541Z
# 留言人數:218
# 按讚數:3754
#
#
# 標題:教你如何有球就閃
# 貼文時間:2020-02-01T18:41:18.149Z
# 留言人數:46
# 按讚數:1864
#
#
# 標題:如何在吵架時拉下臉道歉
# 貼文時間:2020-02-01T07:27:44.905Z
# 留言人數:22
# 按讚數:1161
#
#
# 標題:男友莫名的淚點 (微西斯)
# 貼文時間:2020-02-01T12:50:58.303Z
# 留言人數:18
# 按讚數:1042
#
#
# 標題:女友什麼都自己會就不需要你了
# 貼文時間:2020-02-02T06:54:38.980Z
# 留言人數:67
# 按讚數:882
#
#
# 標題:我們都在成為更好的人
# 貼文時間:2020-02-01T13:58:54.677Z
# 留言人數:21
# 按讚數:625
#
#
# 標題:約炮軟體實用小技巧分享
# 貼文時間:2020-02-01T20:18:24.830Z
# 留言人數:61
# 按讚數:619
#
#
# 標題:妳男友好醜
# 貼文時間:2020-02-02T05:29:43.050Z
# 留言人數:28
# 按讚數:542
#
#
# 標題:一個想到也會笑的回憶。
# 貼文時間:2020-02-02T11:04:35.996Z
# 留言人數:16
# 按讚數:513
#
#
# 標題:男友是在GN上認識的
# 貼文時間:2020-02-01T07:10:30.038Z
# 留言人數:34
# 按讚數:462
#
#
# 標題:謝謝龍山寺送我的男友(⁎⁍̴̛ᴗ⁍̴̛⁎)（長文）
# ...

# %%
print("感情版熱門文章平均留言人數:{}".format(comments/30))
print("感情版版熱門文章平均按讚人數:{}".format(likes/30))
# Out:
# 感情版熱門文章平均留言人數:50.5
# 感情版版熱門文章平均按讚人數:1917.4333333333334

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
r_new = requests.get('https://www.dcard.tw/_api/forums/relationship/posts?popular=false')
response_new = r_new.text
datas_new = json.loads(response_new)
datas_new
# Out:
# [{'id': 233004940,
#   'title': '晚安',
#   'excerpt': '我只想要這樣，單純純粹的喜歡你、陪著你。你喜歡我，我喜歡你，想著對對方好，就是如此純粹簡單，ㄧ旦面臨現實，要如此純粹、簡單，就沒有那麼容易了，就算你真的可以不在乎，你身邊的人真的可以不在乎嗎？而你，真',
#   'anonymousSchool': True,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '42851318-b9e2-4a75-8a05-9fe180becefe',
#   'replyId': None,
#   'createdAt': '2020-02-02T19:05:46.216Z',
#   'updatedAt': '2020-02-02T19:05:46.216Z',
#   'commentCount': 0,
#   'likeCount': 0,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'forumName': '感情',
#   'forumAlias': 'relationship',
#   'gender': 'F',
#   'replyTitle': None,
#   'reportReason': '',
#   'mediaMeta': [],
#   'reactions': [],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233004938,
#   'title': '這樣算玩玩嗎',
# ...

# %%
len(datas_new)
# Out:
# 30

# %%
comments_new=0
likes_new=0
'''
Your Code
'''
for data_new in datas_new:
    print('標題:{}'.format(data_new['title']))
    print('貼文時間:{}'.format(data_new['createdAt']))
    print('留言人數:{}'.format(data_new['commentCount']))
    comments_new=comments_new+data_new['commentCount']
    print('按讚數:{}'.format(data_new['likeCount']))
    likes_new=likes_new+data_new['likeCount']
    print('\n')
# Out:
# 標題:晚安
# 貼文時間:2020-02-02T19:05:46.216Z
# 留言人數:0
# 按讚數:0
#
#
# 標題:這樣算玩玩嗎
# 貼文時間:2020-02-02T19:05:21.797Z
# 留言人數:0
# 按讚數:0
#
#
# 標題:三段感情讓我改變
# 貼文時間:2020-02-02T19:04:08.890Z
# 留言人數:0
# 按讚數:0
#
#
# 標題:抉擇…
# 貼文時間:2020-02-02T18:56:48.769Z
# 留言人數:2
# 按讚數:0
#
#
# 標題:我是原先不知道男友約過炮的過來人
# 貼文時間:2020-02-02T18:55:20.215Z
# 留言人數:0
# 按讚數:0
#
#
# 標題:類似的遭遇
# 貼文時間:2020-02-02T18:53:47.946Z
# 留言人數:0
# 按讚數:1
#
#
# 標題:只要相愛就能永遠在一起嗎？(文長)
# 貼文時間:2020-02-02T18:53:47.229Z
# 留言人數:1
# 按讚數:1
#
#
# 標題:單生狗的聲音
# 貼文時間:2020-02-02T18:52:46.249Z
# 留言人數:1
# 按讚數:0
#
#
# 標題:前女友
# 貼文時間:2020-02-02T18:50:30.665Z
# 留言人數:0
# 按讚數:1
#
#
# 標題:離開的勇氣，是在一次一次失望中凝結的。
# 貼文時間:2020-02-02T18:50:03.326Z
# 留言人數:1
# 按讚數:3
#
#
# 標題:男友家庭問題
# 貼文時間:2020-02-02T18:40:16.451Z
# 留言人數:2
# 按讚數:2
#
#
# 標題:最後的31天...
# 貼文時間:2020-02-02T18:39:48.600Z
# 留言人數:3
# 按讚數:4
#
#
# 標題:分手同居
# 貼文時間:2020-02-02T18:39:08.943Z
# 留言人數:9
# 按讚數:0
#
#
# 標題:遇到無縫接軌的人
# 貼文時間:2020-02-02T18:35:23.874Z
# 留言人數:1
# 按讚數:0
#
#
# 標題:所謂的同居意義
# 貼文時間:2020-02-02T18:30:56.609Z
# 留言人數:1
# 按讚數:6
# ...

# %%
print("感情版非熱門文章平均留言人數:{}".format(comments_new/30))
print("感情版版非熱門文章平均按讚人數:{}".format(likes_new/30))
# Out:
# 感情版非熱門文章平均留言人數:1.7666666666666666
# 感情版版非熱門文章平均按讚人數:1.7
